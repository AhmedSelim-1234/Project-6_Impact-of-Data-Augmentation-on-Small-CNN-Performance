# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
import torchvision
import albumentations as A
from albumentations.pytorch import ToTensorV2
import matplotlib.pyplot as plt
import random, time, os

# %%
# to reproduce in a consistent way
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %%
CIFAR10_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR10_STD  = (0.2470, 0.2435, 0.2616)

# %% [markdown]
# ### Albumentations are implemented here

# %%
train_transforms = A.Compose([
    A.Rotate(limit=15),                                         
    A.Erasing(p=0.5, scale=(0.02, 0.2)),
    A.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD),
    ToTensorV2(),
])

val_transforms = A.Compose([
    A.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD),
    ToTensorV2(),
])

# %%
val_transforms = A.Compose([
    A.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD),
    ToTensorV2(),
])

# %%
class cifar_download(Dataset):
    def __init__(self, root, train=True, transform=None, download=True):
        self.base = torchvision.datasets.CIFAR10(
            root=root, train=train, download=download
        )
        self.transform = transform

    def __len__(self):
        return len(self.base)

    def __getitem__(self, idx):
        img, label = self.base[idx]
        img = np.array(img)                     
        if self.transform:
            img = self.transform(image=img)["image"]
        return img, label

# %%
def make_subset(dataset, fraction: float, seed: int = SEED):
    """Return subsets of dataset"""
    n = int(len(dataset) * fraction)
    rng = np.random.default_rng(seed)
    indices = rng.choice(len(dataset), size=n, replace=False).tolist()
    return Subset(dataset, indices)

# %%
DATA_DIR = os.path.join(os.getcwd(), "data")
BATCH_SIZE = 64
NUM_WORKERS = 2

# %%
train = cifar_download(DATA_DIR, train=True,  transform=train_transforms)
val = cifar_download(DATA_DIR, train=False, transform=val_transforms)

subset_10 = make_subset(train, fraction=0.10)
subset_25 = make_subset(train, fraction=0.25)
subset_50 = make_subset(train, fraction=0.50)

# %%
loaders = {
    "10%": DataLoader(subset_10,  batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
    "25%": DataLoader(subset_25,  batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
    "50%": DataLoader(subset_50,  batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
    "100%": DataLoader(train, batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
}
val_loader = DataLoader(val, batch_size=64, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

# %%
class cnn(nn.Module):
    # in the requiremnents, it asked for a 4-layer
    def __init__(self, num_classes: int = 10, dropout: float = 0.5):
        super().__init__()

        self.conv_block1 = nn.Sequential(
            nn.Conv2d(3,   32,  kernel_size=3, padding=1, bias=False),  
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                       
        )

        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32,  64,  kernel_size=3, padding=1, bias=False),  
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                       
        )

        self.conv_block3 = nn.Sequential(
            nn.Conv2d(64,  128, kernel_size=3, padding=1, bias=False),  
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                       
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),                                                 
            nn.Dropout(p=dropout),
            nn.Linear(128 * 4 * 4, num_classes),                        
        )

    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.classifier(x)
        return x

# %%
def build_model(num_classes=10):
    model = cnn(num_classes=num_classes, dropout=0.5).to(DEVICE)

    
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    # for p in model.parameters():
    #     if p.requires_grad:
    #         sum(p.)
            
    print(f"Trainable parameters: {total_params:,}")
    return model

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def train_one_epoch(model, loader, criterion, optimizer, scaler):
    
    model.train()
    
    running_loss = 0 # losses across batches
    correct = 0 # for accuracy calc
    total = 0 # total samples seen
    
    for imgs, labels in loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE) # for more speed
        
        optimizer.zero_grad() # we want clear grads from last batch not the last epoch
        
        with torch.amp.autocast('cuda'): # for more speed
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        running_loss += loss.item() * imgs.size(0)
        correct += outputs.argmax(1).eq(labels).sum().item()
        total += imgs.size(0)

        # print(running_loss)
        # print(correct)

        avg_loss = running_loss / total
        acc = correct * 100.0 / total
    
    return avg_loss, acc

# %%
@torch.no_grad() # we do not calculate grads when we evaluate
def evaluate(model, loader, criterion):
    
    model.eval()
    
    running_loss = 0 
    correct = 0 
    total = 0 
    
    for imgs, labels in loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        with torch.amp.autocast('cuda'):
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            
        running_loss += loss.item() * imgs.size(0)
        correct += outputs.argmax(1).eq(labels).sum().item()
        total += imgs.size(0)

        # print(running_loss)
        # print(correct)
    
        avg_loss = running_loss / total
        acc = correct * 100.0 / total
            
    return avg_loss, acc

# %%
def run_experiment(subset_name, num_epochs=30):
    print(f"  start: {subset_name} subset  ({num_epochs} epochs)")

    loader = loaders[subset_name]
    model = build_model()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
    scaler = torch.amp.GradScaler('cuda')

    train_losses, train_accs = [], []
    val_losses, val_accs = [], []

    for epoch in range(1, num_epochs + 1):
        t0 = time.time()
        tr_loss, tr_acc = train_one_epoch(model, loader, criterion, optimizer, scaler)
        vl_loss, vl_acc = evaluate(model, val_loader, criterion)
        
        train_losses.append(tr_loss)
        train_accs.append(tr_acc)
        val_losses.append(vl_loss)
        val_accs.append(vl_acc)

        # maybe we should add early stopping here
        print(f"epoch {epoch} | loss {tr_loss:.3f} | val acc {vl_acc:.1f}% | {time.time()-t0:.1f}s")


    best_val = max(val_accs)
    print(f"complete, best val: {best_val:.2f}%")

    ckpt_path = os.path.join(os.getcwd(), f"cnn4layer_{subset_name.replace('%', 'pct')}.pth")
    torch.save(model.state_dict(), ckpt_path)

    history = {"train_loss": train_losses, "train_acc": train_accs,
               "val_loss": val_losses, "val_acc": val_accs}
    
    return history, best_val

# %%
EPOCHS = 30          

results = {}
for subset in ["10%", "25%", "50%", "100%"]:         
    hist, best = run_experiment(subset, num_epochs=EPOCHS)
    results[subset] = {"history": hist, "best_val_acc": best}
# Out:
#   start: 10% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 2.050 | val acc 43.6% | 3.8s
# epoch 2 | loss 1.689 | val acc 47.7% | 3.0s
# epoch 3 | loss 1.572 | val acc 49.0% | 3.0s
# epoch 4 | loss 1.481 | val acc 51.5% | 3.0s
# epoch 5 | loss 1.405 | val acc 50.7% | 3.1s
# epoch 6 | loss 1.329 | val acc 55.2% | 3.0s
# epoch 7 | loss 1.289 | val acc 56.6% | 3.0s
# epoch 8 | loss 1.245 | val acc 52.5% | 3.0s
# epoch 9 | loss 1.196 | val acc 59.2% | 2.9s
# epoch 10 | loss 1.173 | val acc 59.7% | 3.0s
# epoch 11 | loss 1.115 | val acc 57.8% | 3.0s
# epoch 12 | loss 1.090 | val acc 60.1% | 3.0s
# epoch 13 | loss 1.072 | val acc 61.9% | 3.0s
# epoch 14 | loss 1.040 | val acc 59.4% | 3.0s
# epoch 15 | loss 1.011 | val acc 64.0% | 3.1s
# epoch 16 | loss 0.970 | val acc 64.4% | 3.0s
# epoch 17 | loss 0.953 | val acc 61.9% | 3.0s
# epoch 18 | loss 0.912 | val acc 64.0% | 3.0s
# epoch 19 | loss 0.926 | val acc 62.4% | 3.0s
# epoch 20 | loss 0.893 | val acc 65.8% | 2.9s
# epoch 21 | loss 0.867 | val acc 64.6% | 3.0s
# epoch 22 | loss 0.864 | val acc 63.1% | 3.0s
# epoch 23 | loss 0.835 | val acc 67.3% | 3.0s
# epoch 24 | loss 0.817 | val acc 64.0% | 3.0s
# epoch 25 | loss 0.803 | val acc 64.7% | 3.0s
# epoch 26 | loss 0.771 | val acc 66.4% | 3.0s
# epoch 27 | loss 0.768 | val acc 64.0% | 3.0s
# epoch 28 | loss 0.753 | val acc 65.5% | 3.0s
# epoch 29 | loss 0.742 | val acc 66.3% | 3.0s
# epoch 30 | loss 0.707 | val acc 66.0% | 3.0s
# complete, best val: 67.31%
#   start: 25% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 1.843 | val acc 50.4% | 5.1s
# epoch 2 | loss 1.517 | val acc 54.4% | 5.0s
# epoch 3 | loss 1.374 | val acc 56.9% | 5.0s
# epoch 4 | loss 1.296 | val acc 58.3% | 5.0s
# epoch 5 | loss 1.237 | val acc 63.3% | 5.2s
# epoch 6 | loss 1.156 | val acc 62.9% | 5.1s
# epoch 7 | loss 1.125 | val acc 63.1% | 5.1s
# epoch 8 | loss 1.061 | val acc 66.3% | 5.2s
# epoch 9 | loss 1.018 | val acc 64.7% | 5.0s
# epoch 10 | loss 1.012 | val acc 68.3% | 5.0s
# epoch 11 | loss 0.967 | val acc 69.4% | 5.1s
# epoch 12 | loss 0.943 | val acc 68.0% | 5.0s
# epoch 13 | loss 0.929 | val acc 68.4% | 5.1s
# epoch 14 | loss 0.902 | val acc 69.5% | 5.1s
# epoch 15 | loss 0.877 | val acc 70.7% | 5.0s
# epoch 16 | loss 0.869 | val acc 69.2% | 5.1s
# epoch 17 | loss 0.838 | val acc 71.6% | 5.1s
# epoch 18 | loss 0.828 | val acc 69.8% | 5.0s
# epoch 19 | loss 0.817 | val acc 71.9% | 5.0s
# epoch 20 | loss 0.804 | val acc 71.8% | 5.0s
# epoch 21 | loss 0.797 | val acc 71.4% | 5.0s
# epoch 22 | loss 0.763 | val acc 72.3% | 4.9s
# epoch 23 | loss 0.754 | val acc 71.6% | 5.0s
# epoch 24 | loss 0.739 | val acc 72.2% | 5.0s
# epoch 25 | loss 0.737 | val acc 73.1% | 5.0s
# epoch 26 | loss 0.727 | val acc 72.8% | 5.0s
# epoch 27 | loss 0.711 | val acc 74.5% | 5.0s
# epoch 28 | loss 0.689 | val acc 73.7% | 5.0s
# epoch 29 | loss 0.706 | val acc 71.6% | 5.0s
# epoch 30 | loss 0.685 | val acc 73.7% | 5.0s
# complete, best val: 74.48%
#   start: 50% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 1.702 | val acc 53.7% | 8.4s
# epoch 2 | loss 1.366 | val acc 62.3% | 8.4s
# epoch 3 | loss 1.219 | val acc 61.5% | 8.4s
# epoch 4 | loss 1.145 | val acc 65.2% | 8.4s
# epoch 5 | loss 1.065 | val acc 67.1% | 8.3s
# epoch 6 | loss 1.026 | val acc 69.7% | 8.5s
# epoch 7 | loss 0.975 | val acc 69.5% | 8.3s
# epoch 8 | loss 0.948 | val acc 70.5% | 8.3s
# epoch 9 | loss 0.912 | val acc 71.5% | 8.4s
# epoch 10 | loss 0.896 | val acc 73.6% | 8.4s
# epoch 11 | loss 0.867 | val acc 72.1% | 8.4s
# epoch 12 | loss 0.862 | val acc 73.9% | 8.3s
# epoch 13 | loss 0.839 | val acc 72.8% | 8.3s
# epoch 14 | loss 0.823 | val acc 74.2% | 8.4s
# epoch 15 | loss 0.804 | val acc 75.1% | 8.4s
# epoch 16 | loss 0.791 | val acc 75.4% | 8.4s
# epoch 17 | loss 0.786 | val acc 73.3% | 8.4s
# epoch 18 | loss 0.774 | val acc 75.6% | 8.2s
# epoch 19 | loss 0.750 | val acc 76.7% | 8.4s
# epoch 20 | loss 0.749 | val acc 75.5% | 8.4s
# epoch 21 | loss 0.749 | val acc 74.7% | 8.4s
# epoch 22 | loss 0.733 | val acc 76.3% | 8.3s
# epoch 23 | loss 0.724 | val acc 78.0% | 8.3s
# epoch 24 | loss 0.706 | val acc 75.6% | 8.8s
# epoch 25 | loss 0.701 | val acc 77.8% | 9.1s
# epoch 26 | loss 0.703 | val acc 77.1% | 9.0s
# epoch 27 | loss 0.692 | val acc 76.3% | 8.6s
# epoch 28 | loss 0.693 | val acc 76.6% | 8.4s
# epoch 29 | loss 0.669 | val acc 77.4% | 8.4s
# epoch 30 | loss 0.677 | val acc 78.6% | 8.4s
# complete, best val: 78.58%
#   start: 100% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 1.491 | val acc 63.8% | 15.2s
# epoch 2 | loss 1.172 | val acc 67.8% | 15.2s
# epoch 3 | loss 1.044 | val acc 69.1% | 15.1s
# epoch 4 | loss 0.981 | val acc 69.9% | 15.2s
# epoch 5 | loss 0.927 | val acc 73.3% | 15.2s
# epoch 6 | loss 0.895 | val acc 74.2% | 15.1s
# epoch 7 | loss 0.862 | val acc 69.8% | 15.3s
# epoch 8 | loss 0.840 | val acc 75.2% | 15.1s
# epoch 9 | loss 0.815 | val acc 76.5% | 15.4s
# epoch 10 | loss 0.797 | val acc 76.5% | 15.1s
# epoch 11 | loss 0.780 | val acc 77.0% | 15.3s
# epoch 12 | loss 0.772 | val acc 75.6% | 15.1s
# epoch 13 | loss 0.755 | val acc 77.7% | 15.2s
# epoch 14 | loss 0.744 | val acc 78.3% | 15.2s
# epoch 15 | loss 0.737 | val acc 78.5% | 15.2s
# epoch 16 | loss 0.731 | val acc 78.4% | 15.2s
# epoch 17 | loss 0.717 | val acc 78.7% | 15.2s
# epoch 18 | loss 0.718 | val acc 79.1% | 15.2s
# epoch 19 | loss 0.707 | val acc 79.2% | 15.1s
# epoch 20 | loss 0.699 | val acc 79.8% | 15.2s
# epoch 21 | loss 0.688 | val acc 79.7% | 15.2s
# epoch 22 | loss 0.686 | val acc 78.8% | 15.4s
# epoch 23 | loss 0.680 | val acc 80.5% | 15.5s
# epoch 24 | loss 0.680 | val acc 80.7% | 15.4s
# epoch 25 | loss 0.678 | val acc 80.2% | 15.3s
# epoch 26 | loss 0.674 | val acc 80.2% | 15.3s
# epoch 27 | loss 0.665 | val acc 81.2% | 15.1s
# epoch 28 | loss 0.662 | val acc 80.4% | 15.1s
# epoch 29 | loss 0.657 | val acc 79.7% | 15.4s
# epoch 30 | loss 0.658 | val acc 80.3% | 15.4s
# complete, best val: 81.17%

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for label, data in results.items():
    h = data["history"]
    epochs = range(1, len(h["val_acc"]) + 1)
    axes[0].plot(epochs, h["train_acc"], linestyle="--", label=f"{label} train")
    axes[0].plot(epochs, h["val_acc"],   linestyle="-",  label=f"{label} val")
    axes[1].plot(epochs, h["val_loss"],  linestyle="-",  label=f"{label} val loss")

axes[0].set_title("Accuracy vs Epoch")
axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("Accuracy (%)")
axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].set_title("Validation Loss vs Epoch")
axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Loss")
axes[1].legend(); axes[1].grid(True, alpha=0.3)

plt.suptitle("CIFAR-10 4-Layer CNN Albumentations Augmentations", fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(os.getcwd(), "training_curves.png"), dpi=150)
plt.show()

# %%
print(f"{'Subset':>8}  {'Best Val Acc':>13}  {'Train Samples':>14}")
for subset, data in results.items():
    n = len(loaders[subset].dataset)
    print(f"{subset:>8}  {data['best_val_acc']:>12.2f}%  {n:>14,}")
# Out:
#   Subset   Best Val Acc   Train Samples
#      10%         67.31%           5,000
#      25%         74.48%          12,500
#      50%         78.58%          25,000
#     100%         81.17%          50,000
