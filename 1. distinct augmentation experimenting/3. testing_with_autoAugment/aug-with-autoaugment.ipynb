# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
import torchvision
import torchvision.transforms as T
from torchvision.transforms import AutoAugment, AutoAugmentPolicy
import matplotlib.pyplot as plt
from collections import Counter
import random, time, os

# %%
# to reproduce in a consistent way
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %%
CIFAR10_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR10_STD  = (0.2470, 0.2435, 0.2616)

# %% [markdown]
# ### Auto Augment is implemented here

# %%
train_transforms = T.Compose([
   AutoAugment(policy=AutoAugmentPolicy.CIFAR10),        # learned policy
    T.ToTensor(),
    T.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD),
])

val_transforms = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=CIFAR10_MEAN, std=CIFAR10_STD)
])

# %%
DATA_DIR = os.path.join(os.getcwd(), "data")
BATCH_SIZE = 64
NUM_WORKERS = 2

train = torchvision.datasets.CIFAR10(DATA_DIR, train=True,  transform=train_transforms, download = True)
val = torchvision.datasets.CIFAR10(DATA_DIR, train=False, transform=val_transforms, download = True)

# %%
def make_subset(dataset, fraction: float, seed: int = SEED):
    """Return subsets of dataset"""
    n = int(len(dataset) * fraction)
    rng = np.random.default_rng(seed)
    indices = rng.choice(len(dataset), size=n, replace=False).tolist()
    return Subset(dataset, indices)

# %%
subset_10 = make_subset(train, fraction=0.10)
subset_25 = make_subset(train, fraction=0.25)
subset_50 = make_subset(train, fraction=0.50)

# %%
loaders = {
    "10%": DataLoader(subset_10,  batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
    "25%": DataLoader(subset_25,  batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
    "50%": DataLoader(subset_50,  batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
    "100%": DataLoader(train, batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True),
}
val_loader = DataLoader(val, batch_size=64, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

# %%
class cnn(nn.Module):
    # in the requiremnents, it asked for a 4-layer
    def __init__(self, num_classes: int = 10, dropout: float = 0.5):
        super().__init__()

        self.conv_block1 = nn.Sequential(
            nn.Conv2d(3,   32,  kernel_size=3, padding=1, bias=False),  
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                       
        )

        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32,  64,  kernel_size=3, padding=1, bias=False),  
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                       
        )

        self.conv_block3 = nn.Sequential(
            nn.Conv2d(64,  128, kernel_size=3, padding=1, bias=False),  
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),                       
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),                                                 
            nn.Dropout(p=dropout),
            nn.Linear(128 * 4 * 4, num_classes),                        
        )

    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.classifier(x)
        return x

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def build_model(num_classes=10):
    model = cnn(num_classes=num_classes, dropout=0.5).to(DEVICE)

    
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    # for p in model.parameters():
    #     if p.requires_grad:
    #         sum(p.)
            
    print(f"Trainable parameters: {total_params:,}")
    return model

# %%
def train_one_epoch(model, loader, criterion, optimizer, scaler):
    
    model.train()
    
    running_loss = 0 # losses across batches
    correct = 0 # for accuracy calc
    total = 0 # total samples seen
    
    for imgs, labels in loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE) # for more speed
        
        optimizer.zero_grad() # we want clear grads from last batch not the last epoch
        
        with torch.amp.autocast('cuda'): # for more speed
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        running_loss += loss.item() * imgs.size(0)
        correct += outputs.argmax(1).eq(labels).sum().item()
        total += imgs.size(0)

        # print(running_loss)
        # print(correct)

        avg_loss = running_loss / total
        acc = correct * 100.0 / total
    
    return avg_loss, acc

# %%
@torch.no_grad() # we do not calculate grads when we evaluate
def evaluate(model, loader, criterion):
    
    model.eval()
    
    running_loss = 0 
    correct = 0 
    total = 0 
    
    for imgs, labels in loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        with torch.amp.autocast('cuda'):
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            
        running_loss += loss.item() * imgs.size(0)
        correct += outputs.argmax(1).eq(labels).sum().item()
        total += imgs.size(0)

        # print(running_loss)
        # print(correct)
    
        avg_loss = running_loss / total
        acc = correct * 100.0 / total
            
    return avg_loss, acc

# %%
def run_experiment(subset_name, num_epochs=30):
    print(f"  start: {subset_name} subset  ({num_epochs} epochs)")

    loader = loaders[subset_name]
    model = build_model()
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
    scaler = torch.amp.GradScaler('cuda')

    train_losses, train_accs = [], []
    val_losses, val_accs = [], []

    for epoch in range(1, num_epochs + 1):
        t0 = time.time()
        tr_loss, tr_acc = train_one_epoch(model, loader, criterion, optimizer, scaler)
        vl_loss, vl_acc = evaluate(model, val_loader, criterion)
        scheduler.step()
        
        elapsed = time.time() - t0

        train_losses.append(tr_loss)
        train_accs.append(tr_acc)
        val_losses.append(vl_loss)
        val_accs.append(vl_acc)

        # maybe we should add early stopping here
        print(f"epoch {epoch} | loss {tr_loss:.3f} | val acc {vl_acc:.1f}% | {time.time()-t0:.1f}s")


    best_val = max(val_accs)
    print(f"complete, best val: {best_val:.2f}%")

    ckpt_path = os.path.join(os.getcwd(), f"cnn4layer_{subset_name.replace('%', 'pct')}.pth")
    torch.save(model.state_dict(), ckpt_path)

    history = {"train_loss": train_losses, "train_acc": train_accs,
               "val_loss": val_losses, "val_acc": val_accs}
    
    return history, best_val

# %%
EPOCHS = 30          

results = {}
for subset in ["10%", "25%", "50%", "100%"]:         
    hist, best = run_experiment(subset, num_epochs=EPOCHS)
    results[subset] = {"history": hist, "best_val_acc": best}
# Out:
#   start: 10% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 2.267 | val acc 39.4% | 5.4s
# epoch 2 | loss 2.008 | val acc 45.1% | 4.0s
# epoch 3 | loss 1.908 | val acc 46.1% | 3.7s
# epoch 4 | loss 1.822 | val acc 50.1% | 3.7s
# epoch 5 | loss 1.765 | val acc 54.3% | 3.7s
# epoch 6 | loss 1.711 | val acc 55.8% | 3.7s
# epoch 7 | loss 1.678 | val acc 56.6% | 3.8s
# epoch 8 | loss 1.643 | val acc 52.0% | 3.7s
# epoch 9 | loss 1.585 | val acc 56.5% | 3.8s
# epoch 10 | loss 1.577 | val acc 57.9% | 3.8s
# epoch 11 | loss 1.544 | val acc 61.7% | 3.7s
# epoch 12 | loss 1.525 | val acc 60.9% | 3.8s
# epoch 13 | loss 1.487 | val acc 61.2% | 3.7s
# epoch 14 | loss 1.486 | val acc 63.7% | 3.7s
# epoch 15 | loss 1.448 | val acc 65.2% | 3.8s
# epoch 16 | loss 1.423 | val acc 64.6% | 3.7s
# epoch 17 | loss 1.414 | val acc 66.2% | 3.7s
# epoch 18 | loss 1.398 | val acc 65.8% | 3.8s
# epoch 19 | loss 1.381 | val acc 67.2% | 3.7s
# epoch 20 | loss 1.361 | val acc 66.5% | 3.7s
# epoch 21 | loss 1.345 | val acc 67.8% | 3.6s
# epoch 22 | loss 1.334 | val acc 67.6% | 3.8s
# epoch 23 | loss 1.329 | val acc 68.3% | 3.7s
# epoch 24 | loss 1.298 | val acc 69.1% | 3.7s
# epoch 25 | loss 1.287 | val acc 69.2% | 3.7s
# epoch 26 | loss 1.293 | val acc 69.4% | 3.9s
# epoch 27 | loss 1.301 | val acc 69.2% | 3.7s
# epoch 28 | loss 1.284 | val acc 69.3% | 3.7s
# epoch 29 | loss 1.283 | val acc 69.4% | 3.7s
# epoch 30 | loss 1.300 | val acc 69.5% | 3.7s
# complete, best val: 69.46%
#   start: 25% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 2.102 | val acc 47.5% | 6.6s
# epoch 2 | loss 1.857 | val acc 48.9% | 6.6s
# epoch 3 | loss 1.752 | val acc 58.4% | 6.6s
# epoch 4 | loss 1.678 | val acc 59.2% | 6.7s
# epoch 5 | loss 1.616 | val acc 63.8% | 6.5s
# epoch 6 | loss 1.563 | val acc 64.4% | 6.5s
# epoch 7 | loss 1.539 | val acc 62.6% | 6.6s
# epoch 8 | loss 1.484 | val acc 64.8% | 6.5s
# epoch 9 | loss 1.466 | val acc 64.8% | 6.5s
# epoch 10 | loss 1.451 | val acc 69.3% | 6.5s
# epoch 11 | loss 1.423 | val acc 69.5% | 6.5s
# epoch 12 | loss 1.409 | val acc 68.5% | 6.4s
# epoch 13 | loss 1.381 | val acc 70.1% | 6.6s
# epoch 14 | loss 1.357 | val acc 71.3% | 6.4s
# epoch 15 | loss 1.350 | val acc 71.4% | 6.6s
# epoch 16 | loss 1.337 | val acc 72.2% | 6.6s
# epoch 17 | loss 1.307 | val acc 71.5% | 6.4s
# epoch 18 | loss 1.307 | val acc 71.8% | 6.5s
# epoch 19 | loss 1.283 | val acc 73.7% | 6.6s
# epoch 20 | loss 1.274 | val acc 73.1% | 6.5s
# epoch 21 | loss 1.253 | val acc 73.5% | 6.6s
# epoch 22 | loss 1.245 | val acc 73.4% | 6.5s
# epoch 23 | loss 1.242 | val acc 74.4% | 6.4s
# epoch 24 | loss 1.239 | val acc 75.1% | 6.7s
# epoch 25 | loss 1.220 | val acc 74.8% | 6.7s
# epoch 26 | loss 1.221 | val acc 75.1% | 6.5s
# epoch 27 | loss 1.217 | val acc 75.2% | 6.6s
# epoch 28 | loss 1.214 | val acc 75.4% | 6.5s
# epoch 29 | loss 1.205 | val acc 75.3% | 6.4s
# epoch 30 | loss 1.212 | val acc 75.4% | 6.5s
# complete, best val: 75.43%
#   start: 50% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 2.001 | val acc 51.9% | 11.0s
# epoch 2 | loss 1.731 | val acc 61.1% | 11.1s
# epoch 3 | loss 1.611 | val acc 61.1% | 11.1s
# epoch 4 | loss 1.551 | val acc 58.9% | 11.0s
# epoch 5 | loss 1.498 | val acc 66.7% | 11.2s
# epoch 6 | loss 1.461 | val acc 69.0% | 11.3s
# epoch 7 | loss 1.426 | val acc 69.8% | 11.5s
# epoch 8 | loss 1.402 | val acc 68.4% | 11.4s
# epoch 9 | loss 1.384 | val acc 71.9% | 11.2s
# epoch 10 | loss 1.361 | val acc 73.2% | 11.3s
# epoch 11 | loss 1.343 | val acc 73.9% | 11.4s
# epoch 12 | loss 1.324 | val acc 74.3% | 11.4s
# epoch 13 | loss 1.314 | val acc 72.7% | 11.4s
# epoch 14 | loss 1.298 | val acc 75.1% | 11.2s
# epoch 15 | loss 1.281 | val acc 76.0% | 11.3s
# epoch 16 | loss 1.273 | val acc 75.5% | 11.2s
# epoch 17 | loss 1.259 | val acc 76.4% | 11.3s
# epoch 18 | loss 1.247 | val acc 76.9% | 11.3s
# epoch 19 | loss 1.231 | val acc 77.2% | 11.2s
# epoch 20 | loss 1.217 | val acc 76.9% | 11.1s
# epoch 21 | loss 1.207 | val acc 77.0% | 11.0s
# epoch 22 | loss 1.201 | val acc 78.1% | 11.2s
# epoch 23 | loss 1.188 | val acc 78.7% | 11.2s
# epoch 24 | loss 1.179 | val acc 79.0% | 11.6s
# epoch 25 | loss 1.174 | val acc 78.6% | 11.4s
# epoch 26 | loss 1.164 | val acc 79.0% | 11.3s
# epoch 27 | loss 1.162 | val acc 79.3% | 11.2s
# epoch 28 | loss 1.159 | val acc 79.1% | 11.2s
# epoch 29 | loss 1.160 | val acc 79.3% | 11.2s
# epoch 30 | loss 1.155 | val acc 79.1% | 11.4s
# complete, best val: 79.28%
#   start: 100% subset  (30 epochs)
# Trainable parameters: 113,962
# epoch 1 | loss 1.837 | val acc 60.3% | 20.8s
# epoch 2 | loss 1.575 | val acc 66.3% | 20.8s
# epoch 3 | loss 1.483 | val acc 68.9% | 20.6s
# epoch 4 | loss 1.423 | val acc 70.8% | 20.7s
# epoch 5 | loss 1.383 | val acc 73.7% | 20.7s
# epoch 6 | loss 1.354 | val acc 74.9% | 20.5s
# epoch 7 | loss 1.337 | val acc 75.6% | 20.7s
# epoch 8 | loss 1.318 | val acc 76.1% | 20.3s
# epoch 9 | loss 1.297 | val acc 76.3% | 20.1s
# epoch 10 | loss 1.284 | val acc 76.9% | 20.5s
# epoch 11 | loss 1.269 | val acc 77.1% | 20.9s
# epoch 12 | loss 1.254 | val acc 78.5% | 20.9s
# epoch 13 | loss 1.246 | val acc 79.1% | 20.8s
# epoch 14 | loss 1.230 | val acc 79.4% | 20.7s
# epoch 15 | loss 1.222 | val acc 79.8% | 20.5s
# epoch 16 | loss 1.211 | val acc 79.8% | 20.8s
# epoch 17 | loss 1.199 | val acc 80.4% | 21.0s
# epoch 18 | loss 1.187 | val acc 80.8% | 21.0s
# epoch 19 | loss 1.175 | val acc 80.9% | 20.9s
# epoch 20 | loss 1.166 | val acc 81.3% | 20.9s
# epoch 21 | loss 1.161 | val acc 81.5% | 20.6s
# epoch 22 | loss 1.145 | val acc 81.8% | 21.0s
# epoch 23 | loss 1.134 | val acc 81.8% | 20.8s
# epoch 24 | loss 1.129 | val acc 82.4% | 20.9s
# epoch 25 | loss 1.127 | val acc 81.9% | 20.7s
# epoch 26 | loss 1.123 | val acc 82.4% | 20.7s
# epoch 27 | loss 1.119 | val acc 82.4% | 21.1s
# epoch 28 | loss 1.110 | val acc 82.5% | 20.9s
# epoch 29 | loss 1.110 | val acc 82.7% | 20.6s
# epoch 30 | loss 1.111 | val acc 82.8% | 20.6s
# complete, best val: 82.79%

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for label, data in results.items():
    h = data["history"]
    epochs = range(1, len(h["val_acc"]) + 1)
    axes[0].plot(epochs, h["train_acc"], linestyle="--", label=f"{label} train")
    axes[0].plot(epochs, h["val_acc"],   linestyle="-",  label=f"{label} val")
    axes[1].plot(epochs, h["val_loss"],  linestyle="-",  label=f"{label} val loss")

axes[0].set_title("Accuracy vs Epoch")
axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("Accuracy (%)")
axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].set_title("Validation Loss vs Epoch")
axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Loss")
axes[1].legend(); axes[1].grid(True, alpha=0.3)

plt.suptitle("CIFAR-10 4-Layer CNN AutoAugmnent", fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(os.getcwd(), "training_curves.png"), dpi=150)
plt.show()

# %%
print(f"{'Subset':>8}  {'Best Val Acc':>13}  {'Train Samples':>14}")
for subset, data in results.items():
    n = len(loaders[subset].dataset)
    print(f"{subset:>8}  {data['best_val_acc']:>12.2f}%  {n:>14,}")
# Out:
#   Subset   Best Val Acc   Train Samples
#      10%         69.46%           5,000
#      25%         75.43%          12,500
#      50%         79.28%          25,000
#     100%         82.79%          50,000
